# %%
def comparacao(n1, n2):
    if n1 > n2:
        print(f"{n1} é maior que {n2}")
    elif n1 < n2:
        print(f"{n2} é maior que {n1}")
    else:
      print(f"{n1} é igual a {n2}")


n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))

comparacao(n1, n2)
# Out:
# Digite o primeiro número: 1
# Digite o segundo número: 1
# 1.0 é igual a 1.0

# %%
def reverter_lista(lista):
    lista.reverse()
    return lista

numeros = [1, 2, 3, 4]
reverter_lista(numeros)
print(numeros)
# Out:
# [4, 3, 2, 1]

# %%
def reverter_lista(lista):
    lista.reverse()
    return lista

numeros = []

while True:
    entrada = input("Digite um número (ou 'fim' para terminar): ")
    if entrada.lower() == 'fim':
        break
    numeros.append(int(entrada))

reverter_lista(numeros)
print("Lista invertida:", numeros)
# Out:
# Digite um número (ou 'fim' para terminar): 1
# Digite um número (ou 'fim' para terminar): 2
# Digite um número (ou 'fim' para terminar): 3
# Digite um número (ou 'fim' para terminar): 4
# Digite um número (ou 'fim' para terminar): 5
# Digite um número (ou 'fim' para terminar): 6
# Digite um número (ou 'fim' para terminar): 7
# Digite um número (ou 'fim' para terminar): fim
# Lista invertida: [7, 6, 5, 4, 3, 2, 1]

# %%
def fatorial(n):
    resultado = 1
    for i in range(n, 0, -1):
        resultado *= i
    return resultado

numero = int(input("Digite um número para calcular o fatorial: "))
print(f"O fatorial de {numero} é: {fatorial(numero)}")
# Out:
# Digite um número para calcular o fatorial: 4
# O fatorial de 4 é: 24

# %%
def fatorial(n):
    resultado = 1
    passos = ""

    for i in range(n, 0, -1):
        resultado *= i
        passos += str(i)
        if i > 1:
            passos += " x "

    print(f"{n}! = {passos} = {resultado}")
    return resultado

numero = int(input("Digite um número para calcular o fatorial: "))
fatorial(numero)
# Out:
# Digite um número para calcular o fatorial: 4
# 4! = 4 x 3 x 2 x 1 = 24
# 24

# %%
import pandas as pd

df = pd.read_csv("/content/dataset_prova.csv")
df.shape #propriedade e nao funcao
#shape me da linhas e colunas
df.tail(3)
df.head(3)
# Out:
#         Setor  Idade  Experiência (anos)  Salário (R$)  \
# 0          RH     39                  18   9225.487461
# 1  Financeiro     47                  29  11436.227507
# 2      Vendas     55                  37   7363.555229
#
#    Horas de Trabalho/Semana  Satisfação (1-5)
# 0                 38.423171                 4
# 1                 30.729479                 5
# 2                 49.364169                 4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Setor                     100 non-null    object
#  1   Idade                     100 non-null    int64
#  2   Experiência (anos)        100 non-null    int64
#  3   Salário (R$)              100 non-null    float64
#  4   Horas de Trabalho/Semana  100 non-null    float64
#  5   Satisfação (1-5)          100 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 4.8+ KB

# %%
df.describe()
# Out:
#             Idade  Experiência (anos)  Salário (R$)  Horas de Trabalho/Semana  \
# count  100.000000          100.000000    100.000000                100.000000
# mean    41.070000           21.680000   8945.048592                 45.262704
# std     11.049252           11.223964   3408.973265                  9.004398
# min     22.000000            1.000000   3060.739006                 30.431805
# 25%     30.750000           11.000000   5904.054316                 38.329755
# 50%     43.500000           23.500000   9290.647201                 46.079846
# 75%     50.000000           31.250000  11463.708294                 52.826489
# max     58.000000           39.000000  14827.805449                 59.701616
#
#        Satisfação (1-5)
# count        100.000000
# mean           2.980000
# std            1.456299
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000

# %%
colunas =['Idade', 'Setor']
df[colunas].head(1)
# Out:
#    Idade Setor
# 0     39    RH

# %%
df1 = df[colunas].copy()
df1
# Out:
#     Idade       Setor
# 0      39          RH
# 1      47  Financeiro
# 2      55      Vendas
# 3      31          RH
# 4      57          RH
# ..    ...         ...
# 95     58          TI
# 96     54          TI
# 97     45  Financeiro
# 98     36          TI
# 99     53      Vendas
#
# [100 rows x 2 columns]

# %%
df1.iloc[1,1]
df.loc[1,'Setor']
# Out:
# 'Financeiro'

# %%
df1[ (df1['Idade'] > 50) & (df1['Setor']=='Vendas')]
# Out:
#     Idade   Setor
# 2      55  Vendas
# 6      52  Vendas
# 30     56  Vendas
# 31     56  Vendas
# 63     53  Vendas
# 67     58  Vendas
# 82     51  Vendas
# 99     53  Vendas

# %%
df.head(1)
# Out:
#   Setor  Idade  Experiência (anos)  Salário (R$)  Horas de Trabalho/Semana  \
# 0    RH     39                  18   9225.487461                 38.423171
#
#    Satisfação (1-5)
# 0                 4

# %%
df['Idade começou a trabalhar'] = df['Idade'] - df['Experiência (anos)']
df
# Out:
#          Setor  Idade  Experiência (anos)  Salário (R$)  \
# 0           RH     39                  18   9225.487461
# 1   Financeiro     47                  29  11436.227507
# 2       Vendas     55                  37   7363.555229
# 3           RH     31                  11  14661.384993
# 4           RH     57                  36  14549.367539
# ..         ...    ...                 ...           ...
# 95          TI     58                  39   9031.645117
# 96          TI     54                  34   9922.846616
# 97  Financeiro     45                  27   8910.212326
# 98          TI     36                  18   5342.915854
# 99      Vendas     53                  34  11669.425383
#
#     Horas de Trabalho/Semana  Satisfação (1-5)  Idade começou a trabalhar
# 0                  38.423171                 4                         21
# 1                  30.729479                 5                         18
# ...

# %%
df.rename(columns={'Idade começou a trabalhar': 'Inicio de Atividade'})
df
# Out:
#          Setor  Idade  Experiência (anos)  Salário (R$)  \
# 0           RH     39                  18   9225.487461
# 1   Financeiro     47                  29  11436.227507
# 2       Vendas     55                  37   7363.555229
# 3           RH     31                  11  14661.384993
# 4           RH     57                  36  14549.367539
# ..         ...    ...                 ...           ...
# 95          TI     58                  39   9031.645117
# 96          TI     54                  34   9922.846616
# 97  Financeiro     45                  27   8910.212326
# 98          TI     36                  18   5342.915854
# 99      Vendas     53                  34  11669.425383
#
#     Horas de Trabalho/Semana  Satisfação (1-5)  Inicio de Atividade
# 0                  38.423171                 4                   21
# 1                  30.729479                 5                   18
# 2                  49.364169                 4                   18
# ...

# %%
df_sem_satisfacao = df.drop(columns=['Satisfação (1-5)'])
df_sem_satisfacao
# Out:
#          Setor  Idade  Experiência (anos)  Salário (R$)  \
# 0           RH     39                  18   9225.487461
# 1   Financeiro     47                  29  11436.227507
# 2       Vendas     55                  37   7363.555229
# 3           RH     31                  11  14661.384993
# 4           RH     57                  36  14549.367539
# ..         ...    ...                 ...           ...
# 95          TI     58                  39   9031.645117
# 96          TI     54                  34   9922.846616
# 97  Financeiro     45                  27   8910.212326
# 98          TI     36                  18   5342.915854
# 99      Vendas     53                  34  11669.425383
#
#     Horas de Trabalho/Semana
# 0                  38.423171
# 1                  30.729479
# 2                  49.364169
# 3                  35.313320
# 4                  58.213758
# ..                       ...
# 95                 52.735383
# 96                 30.431805
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Setor                     100 non-null    object
#  1   Idade                     100 non-null    int64
#  2   Experiência (anos)        100 non-null    int64
#  3   Salário (R$)              100 non-null    float64
#  4   Horas de Trabalho/Semana  100 non-null    float64
#  5   Satisfação (1-5)          100 non-null    int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 4.8+ KB
